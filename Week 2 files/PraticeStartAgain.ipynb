# %%
import cv2
import numpy as np

# %%
myImage = cv2.imread("D:/Personal/Images/Umar.png",0)
print (myImage)
# Out:
# [[127 127 127 ... 127 127 127]
#  [127 127 127 ... 127 127 127]
#  [127 127 127 ... 127 127 127]
#  ...
#  [127 127 127 ... 127 127 127]
#  [127 127 127 ... 127 127 127]
#  [127 127 127 ... 127 127 127]]

# %%
myImage.shape
# Out:
# (408, 612)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(myImage)

# %%
# %matplotlib notebook
plt.imshow(myImage,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image = cv2.cvtColor(myImage,cv2.COLOR_BGR2RGB)

# %matplotlib inline
plt.imshow(image)

# %%
plt.imshow(myImage[:,::-1],cmap='gray')
